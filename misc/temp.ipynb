# %%
f = open("losses/all_loss_obj_lane_0p1.txt")
w = open("losses/all_loss_0p1.csv", "a")

# %%
loss1 = []
loss2 = []
loss3 = []
loss4 = []
loss5 = []
loss6 = []
loss7 = []
loss8 = []
w.write("total_loss,loss_cls_obj,loss_box_obj,loss_dfl_obj, cls_loss_lane, reg_xytl_loss_lane, seg_loss_lane, iou_loss_lane\n")
for i, line in enumerate(f):
    loss1 += [float(line.split(",")[0])]
    loss2 += [float(line.split(",")[1])]
    loss3 += [float(line.split(",")[2])]
    loss4 += [float(line.split(",")[3])]
    loss5 += [float(line.split(",")[4])]
    loss6 += [float(line.split(",")[5])]
    loss7 += [float(line.split(",")[6])]
    loss8 += [float(line.split(",")[7])]
    if not (i+1)%3704:
        w.write(f"{sum(loss1)/3704},{sum(loss2)/3704},{sum(loss3)/3704},{ sum(loss4)/3704}, {sum(loss5)/3704}, {sum(loss6)/3704}, {sum(loss7)/3704}, {sum(loss8)/3704},\n")
        loss1 = []
        loss2 = []
        loss3 = []
        loss4 = []
        loss5 = []
        loss6 = []
        loss7 = []
        loss8 = []

# %%
w.close()

# %%
import pandas as pd
df = pd.read_csv('losses/all_loss.csv', index_col=False)  # Replace with your actual file path

# %%
df.iloc[:,1:3].sum(axis = 1)
# Out:
# 0     2.022639
# 1     2.006757
# 2     1.978553
# 3     1.957616
# 4     1.945022
# 5     1.935290
# 6     1.924375
# 7     1.921130
# 8     1.908649
# 9     1.903501
# 10    1.900176
# 11    1.895540
# 12    1.885165
# 13    1.884861
# 14    1.885117
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy

# Read the CSV file (with headers in the first row)
df = pd.read_csv('losses/all_loss.csv', index_col=False)  # Replace with your actual file path
df2 = pd.read_csv('losses/all_loss_obj.csv', index_col=False)
df3 = pd.read_csv('losses/all_loss_0p1.csv', index_col=False)
# Plot all columns
plt.figure(figsize=(12, 6))
lw = 1
# for column in df.iloc[:,1:4].columns:
#     plt.plot(df[column], label="scaler = 1", linewidth=lw, color = 'black')
#     plt.plot(df2[column], label="scaler = 0", linewidth=lw, color = 'red')
#     plt.plot(df3[column], label="scaler = 0.1", linewidth=lw, color = 'blue')
#     lw *=2

plt.plot(df.iloc[:,1:4].sum(axis = 1), label="scalar = 1", linewidth=lw, color = 'black')
plt.plot(df2.iloc[:,1:4].sum(axis = 1), label="scalar = 0", linewidth=lw, color = 'red')
plt.plot(df3.iloc[:,1:4].sum(axis = 1), label="scalar = 0.1", linewidth=lw, color = 'blue')

# for column in df2.iloc[:,1:4].columns:
#     plt.plot(df2[column], label=column)
# for column in df3.iloc[:,1:4].columns:
#     plt.plot(df3[column], label=column)

# Add plot details
plt.xlabel('Epock')
plt.ylabel('Loss')
plt.title('Plot of Object Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy

# Read the CSV file (with headers in the first row)
df = pd.read_csv('losses/all_loss.csv', index_col=False)  # Replace with your actual file path
df2 = pd.read_csv('losses/all_loss_0p1.csv', index_col=False)
# Plot all columns
plt.figure(figsize=(12, 6))
lw = 1
# for column in df.iloc[:,4:8].columns:
#     plt.plot(df[column], label="scalar = 1", linewidth=lw, color='red')
#     plt.plot(df2[column], label="scalar = 0.1", linewidth=lw, color='blue')
#     lw += 1
    
plt.plot(df.iloc[:,4:8].sum(axis = 1), label="scalar = 1", linewidth=lw, color = 'red')
plt.plot(df2.iloc[:,4:8].sum(axis = 1), label="scalar = 0.1", linewidth=lw, color = 'blue')

# for column in df2.iloc[:,1:4].columns:
#     plt.plot(df2[column], label=column)
# for column in df3.iloc[:,1:4].columns:
#     plt.plot(df3[column], label=column)

# Add plot details
plt.xlabel('Epock')
plt.ylabel('Loss')
plt.title('Plot of Lane Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy

# Read the CSV file (with headers in the first row)
df = pd.read_csv('losses/all_loss.csv', index_col=False)  # Replace with your actual file path
df2 = pd.read_csv('losses/all_loss_0p1.csv', index_col=False)
# Plot all columns
plt.figure(figsize=(12, 6))
lw = 1
for column in df.iloc[:,:1].columns:
    plt.plot(df[column], label="scalar = 1", linewidth=lw, color='red')
    plt.plot(df2[column], label="scalar = 0.1", linewidth=lw, color='blue')
    lw += 1
# for column in df2.iloc[:,1:4].columns:
#     plt.plot(df2[column], label=column)
# for column in df3.iloc[:,1:4].columns:
#     plt.plot(df3[column], label=column)

# Add plot details
plt.xlabel('Epock')
plt.ylabel('Loss')
plt.title('Plot of All Losses')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
df3.iloc[:,-1:]
# Out:
#       mAP
# 0   0.281
# 1   0.294
# 2   0.302
# 3   0.304
# 4   0.308
# 5   0.304
# 6   0.310
# 7   0.312
# 8   0.303
# 9   0.309
# 10  0.308
# 11  0.310
# 12  0.317
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy

# Read the CSV file (with headers in the first row)
df = pd.read_csv('losses/all_loss.csv', index_col=False)  # Replace with your actual file path
df2 = pd.read_csv('losses/all_loss_obj.csv', index_col=False)
df3 = pd.read_csv('losses/all_loss_0p1.csv', index_col=False)
dfr = pd.read_csv("losses/ref_loss_mAP_obj.csv", index_col=False)
# Plot all columns
plt.figure(figsize=(12, 6))
lw = 1
# for column in df.iloc[:,1:4].columns:
#     plt.plot(df[column], label="scaler = 1", linewidth=lw, color = 'black')
#     plt.plot(df2[column], label="scaler = 0", linewidth=lw, color = 'red')
#     plt.plot(df3[column], label="scaler = 0.1", linewidth=lw, color = 'blue')
#     lw *=2

plt.plot(df.iloc[:,-1:].sum(axis = 1), label="scalar = 1", linewidth=lw, color = 'black')
plt.plot(df2.iloc[:,-1:].sum(axis = 1), label="scalar = 0", linewidth=lw, color = 'red')
plt.plot(df3.iloc[:,-1:].sum(axis = 1), label="scalar = 0.1", linewidth=lw, color = 'blue')
plt.plot(dfr.iloc[:,-1:].sum(axis = 1), label="reference", linewidth=lw, color = 'green')

# for column in df2.iloc[:,1:4].columns:
#     plt.plot(df2[column], label=column)
# for column in df3.iloc[:,1:4].columns:
#     plt.plot(df3[column], label=column)

# Add plot details
plt.xlabel('Epock')
plt.ylabel('mAP')
plt.title('Object mAP')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
df1 = pd.read_csv("scores/all_scores_final_model.txt", header=None)

# %%
df1
# Out:
#                                                     0  \
# 0   tp: [ 6837.   193. 74078.  2186.   862.     0....
# 1   tp: [ 6122.   234. 73013.  2305.   779.     0....
# 2   tp: [ 6224.   245. 71595.  2242.   745.     0....
# 3   tp: [ 6291.   213. 75247.  2323.   890.     0....
# 4   tp: [ 5933.   228. 73776.  2360.   891.     0....
# 5   tp: [ 6544.   219. 73523.  2337.   911.     0....
# 6   tp: [ 6562.   230. 72951.  2507.   771.     0....
# 7   tp: [ 6598.   242. 73448.  2236.   887.     0....
# 8   tp: [ 6256.   256. 72922.  2312.   820.     0....
# 9   tp: [ 6747.   256. 71889.  2137.   873.     0....
# 10  tp: [ 5616.   220. 72379.  2367.   884.     0....
# 11  tp: [ 6593.   266. 73309.  2270.   822.     0....
# 12  tp: [ 6461.   249. 74055.  2405.   893.     0....
# 13  tp: [ 6728.   270. 73506.  2388.   870.     0....
# 14  tp: [ 6820.   263. 72360.  2407.   810.     0....
# 15  tp: [ 6430.   267. 74242.  2477.   834.     0....
# ...

# %%
df2 = df1.iloc[:,2:]

# %%
import re

for col in df2.columns:
    df2[col] = df2[col].str.extract(r'([0-9.]+)').astype(float)
# Out:
# /tmp/ipykernel_2458384/3174676839.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[col] = df2[col].str.extract(r'([0-9.]+)').astype(float)
# /tmp/ipykernel_2458384/3174676839.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[col] = df2[col].str.extract(r'([0-9.]+)').astype(float)
# /tmp/ipykernel_2458384/3174676839.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df2[5]
# Out:
# 0     0.294256
# 1     0.297759
# 2     0.291238
# 3     0.302841
# 4     0.312619
# 5     0.306345
# 6     0.308244
# 7     0.308309
# 8     0.310688
# 9     0.313206
# 10    0.313157
# 11    0.317306
# 12    0.313144
# 13    0.319052
# 14    0.315079
# 15    0.315719
# 16    0.321575
# 17    0.315950
# 18    0.319514
# 19    0.321192
# 20    0.327736
# 21    0.323645
# 22    0.327261
# 23    0.324538
# 24    0.319262
# 25    0.324478
# 26    0.319361
# 27    0.319959
# 28    0.325866
# 29    0.325476
# 30    0.326426
# 31    0.325596
# 32    0.316101
# 33    0.326757
# 34    0.327839
# 35    0.324992
# 36    0.325423
# 37    0.325570
# 38    0.322135
# 39    0.317671
# 40    0.325931
# 41    0.327751
# 42    0.328426
# 43    0.330097
# 44    0.328743
# 45    0.324908
# 46    0.326265
# 47    0.328138
# 48    0.336891
# 49    0.329583
# Name: 5, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy

dfr = pd.read_csv("losses/ref_loss_mAP_obj.csv", index_col=False)

plt.figure(figsize=(12, 6))
lw = 1

plt.plot(dfr.iloc[:,-1:].sum(axis = 1), label="reference", linewidth=lw, color = 'green')
plt.plot(df2[5], label="combined, scaling = 0.1", linewidth=lw, color = 'blue')


# Add plot details
plt.xlabel('Epoch')
plt.ylabel('mAP')
plt.title('Object mAP')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
v_pc_cs = pd.read_csv("/home/mmm9886/Desktop/Capstone_Implementation/clrnet/all_scores_vehicle_only_pcgrad_divergentneck_cross_stitch_v8n.txt", header=None)
v_pc_cs_pre = pd.read_csv("/home/mmm9886/Desktop/Capstone_Implementation/clrnet/all_scores_vehicle_only_pcgrad_v8n.txt", header=None)
v_pc = pd.read_csv("/home/mmm9886/Desktop/Capstone_Implementation/clrnet/all_scores_vehicle_only_pcgrad_control_v8n.txt", header=None)
v_pc_cs_scale = pd.read_csv("/home/mmm9886/Desktop/Capstone_Implementation/clrnet/all_scores_vehicle_only_pcgrad_divergentneck_cross_stitch_v8n_scaled2.txt", header=None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       3 v_pc_cs_pre = pd.read_csv("/home/mmm9886/Desktop/Capstone_Implementation/clrnet/all_scores_vehicle_only_pcgrad_v8n.txt", header=None)
#       4 v_pc = pd.read_csv("/home/mmm9886/Desktop/Capstone_Implementation/clrnet/all_scores_vehicle_only_pcgrad_control_v8n.txt", header=None)
# ----> 5 v_pc_cs_scale = pd.read_csv("/home/mmm9886/Desktop/Capstone_Implementation/clrnet/all_scores_vehicle_only_pcgrad_divergentneck_cross_stitch_v8n_scaled2.txt", header=None)
#
# ...

# %%
plt.figure(figsize=(12, 6))

plt.plot(v_pc_cs_pre[4], label="pcgrad + cross_stitch + not fully pretrained", color = 'green')
plt.plot(v_pc_cs[4], label="pcgrad + cross_stitch", color = 'blue')
plt.plot(v_pc[4], label="pcgrad", color = 'red')


# Add plot details
plt.xlabel('Epoch')
plt.ylabel('mAP@50')
plt.title('Object mAP@50')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.plot(v_pc_cs_pre[5], label="pcgrad + cross_stitch + not fully pretrained", color = 'green')
plt.plot(v_pc_cs[5], label="pcgrad + cross_stitch", color = 'blue')
plt.plot(v_pc[5], label="pcgrad", color = 'red')


# Add plot details
plt.xlabel('Epoch')
plt.ylabel('mAP@50:95')
plt.title('Object mAP@50:95')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy
v_pc_cs = pd.read_csv("all_scores_pcgrad_divergentneck_cross_stitch2_v8n.txt", header=None)
v_pc = pd.read_csv("all_scores_pcgrad_control2_v8n.txt", header=None)
v_pc_cs_scale = pd.read_csv("all_scores_pcgrad_divergentneck_cross_stitch_scaled_v8n.txt", header=None)

# %%
plt.figure(figsize=(12, 6))

plt.plot(v_pc[3], label="pcgrad", color = 'red')
plt.plot(v_pc_cs[3], label="pcgrad + cross_stitch", color = 'blue')
plt.plot(v_pc_cs_scale[3], label="pcgrad + cross_stitch + scaled", color = 'green')


# Add plot details
plt.xlabel('Epoch')
plt.ylabel('mAP@50:95')
plt.title('Object mAP@50:95')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.plot(v_pc[2], label="pcgrad", color = 'red')
plt.plot(v_pc_cs[2], label="pcgrad + cross_stitch", color = 'blue')
plt.plot(v_pc_cs_scale[2], label="pcgrad + cross_stitch + scaled", color = 'green')


# Add plot details
plt.xlabel('Epoch')
plt.ylabel('mAP@50')
plt.title('Object mAP@50')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()
